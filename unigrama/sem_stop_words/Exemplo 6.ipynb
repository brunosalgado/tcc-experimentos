# %% [markdown]
# # K-Nearest Neighbors
# ### Modelo 06
# - CountVectorizer
# - Base B
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, mean_squared_error, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_b.csv')

df.head()
# Out:
#                       nome categoria
# 0                   BRAHMA    BRAHMA
# 1             BRAHMA 550ML    BRAHMA
# 2     BRAHMA CERV 350ML LT    BRAHMA
# 3     BRAHMA CERVEJA 350ML    BRAHMA
# 4  BRAHMA CERVEJA 350ML LT    BRAHMA

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                       nome  categoria
# 0                   BRAHMA          0
# 1             BRAHMA 550ML          0
# 2     BRAHMA CERV 350ML LT          0
# 3     BRAHMA CERVEJA 350ML          0
# 4  BRAHMA CERVEJA 350ML LT          0

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome, 
    df.categoria,
    test_size = 0.3, 
    random_state = 42
)

# %% [markdown]
# #### Define CountVectorizer

# %%
count_vectorizer = CountVectorizer(
    tokenizer=token,
    ngram_range=(1,1)
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = count_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Busca melhor valor para k

# %%
best_rmse = 1
k_neighbors = 0

k_range = range(1, 31)
k_scores = []
for k in k_range:
    model = KNeighborsClassifier(n_neighbors=k)
    loss = abs(cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error'))
    k_scores.append(loss.mean())
    if loss.mean() < best_rmse:
        best_rmse = loss.mean()
        k_neighbors = k
plt.plot(k_range, k_scores)
plt.xlabel('Valor de K')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# #### Cria um classificador kNN

# %%
knn = KNeighborsClassifier(n_neighbors = k_neighbors)

# %% [markdown]
# #### Treina o classificador

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = knn.predict(count_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 97.0
# precisao: 97.1

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = count_vectorizer.transform([X_test.values[i]])
    pred = knn.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                         Nome     Categoria Original  \
# 0                       SUCO INT LARANJA 1LT  SUCO LARANJA INTEGRAL
# 1             IFOOD SUCO DE LARANJA INTG 300  SUCO LARANJA INTEGRAL
# 2                      SUCO DE UVA SPRES 2LT               SUCO UVA
# 3      SUCO ALIANCA UVA BRANCO INTEG GFA 1.5      SUCO UVA INTEGRAL
# 4                   KAPO SUCO UVA INTG 200ML      SUCO UVA INTEGRAL
# 5   SUCO DE UVA TINTO INT HUGO PIETRO 1500ML      SUCO UVA INTEGRAL
# 6                       BEB SUCO DE UVA INT       SUCO UVA INTEGRAL
# 7                          SUCO DE UVA INTEG      SUCO UVA INTEGRAL
# 8                      COCA COLA 2L DIVERSOS              COCA-COLA
# 9                   REFRI CINI GUARANA 600ML      CINI REFRIGERANTE
# 10          CAMPO LARGO SUCO PET UVA LEV 1 3               SUCO UVA
# 11     SUCO NATURAL ONE LARANJA INT GFA 900M  SUCO LARANJA INTEGRAL
# 12                       SPRITE ZERO M PR CP                 SPRITE
# 13                        SUCO INT UVA 200ML      SUCO UVA INTEGRAL
# 14          CAMPO LARGO SUCO PET LARANJA 900           SUCO LARANJA
# 15        MIOLO SUNNY DAYS SUCO DE UVA 300ML               SUCO UVA
# 16       SUCO CAMPO LARGO COLD 900ML LARANJA           SUCO LARANJA
# 17            SUCO LARANJA CAMPO LARGO 900ML           SUCO LARANJA
# 18                 SUCO TANG UVA INTENSA 25G      SUCO UVA INTEGRAL
# 19     SUCO PANIZZON UVA BRANCO INTEG GFA 1.      SUCO UVA INTEGRAL
# 20            REFRIG FANTA SPRITE KUAT 600ML                   KUAT
# 21        SUCO ALIANCA UVA TINTO INTEG 450ML      SUCO UVA INTEGRAL
# 22        DEL VALLE LARANJA INTG 1L 100 SUCO  SUCO LARANJA INTEGRAL
# 23                        D SUCO DE UVA INT       SUCO UVA INTEGRAL
# 24                      REFRIG COCA COLA ZER              COCA-COLA
# 25         SUCO DEL VALLE FRESH LARANJA 1 5L           SUCO LARANJA
# 26        SUCO DE LARANJA CAMPO LARGO 900 ML           SUCO LARANJA
#
#                      Pred
# 0            SUCO LARANJA
# 1            SUCO LARANJA
# 2       SUCO UVA INTEGRAL
# 3                SUCO UVA
# 4                SUCO UVA
# 5                SUCO UVA
# 6                SUCO UVA
# 7                SUCO UVA
# 8          COCA-COLA ZERO
# 9       GUARANA ANTARTICA
# 10      SUCO UVA INTEGRAL
# 11           SUCO LARANJA
# 12         COCA-COLA ZERO
# 13               SUCO UVA
# 14  SUCO LARANJA INTEGRAL
# 15      SUCO UVA INTEGRAL
# 16  SUCO LARANJA INTEGRAL
# 17  SUCO LARANJA INTEGRAL
# 18               SUCO UVA
# 19               SUCO UVA
# 20                 SPRITE
# 21               SUCO UVA
# 22           SUCO LARANJA
# 23               SUCO UVA
# 24         COCA-COLA ZERO
# 25  SUCO LARANJA INTEGRAL
# 26  SUCO LARANJA INTEGRAL

# %%
model = TSNE(n_components=2, init='pca', random_state=0)
transformed = model.fit_transform(X_train.todense())

fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], c=[plt.cm.tab20b(float(g)/15)], s=20, label = le.inverse_transform([g])[0])

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Matriz de Confusão

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_confusion_matrix(
    knn,
    count_vectorizer.transform(X_test).toarray(),
    y_test,
    display_labels=np.unique(le.inverse_transform(y_test)),
    cmap=plt.cm.Blues,
    normalize='true',
    ax=ax,
    xticks_rotation='vertical'
)
