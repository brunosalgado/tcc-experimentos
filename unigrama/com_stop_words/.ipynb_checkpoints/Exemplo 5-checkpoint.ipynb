# %% [markdown]
# # K-Nearest Neighbors
# ### Modelo 05
# - CountVectorizer
# - Base A
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, mean_squared_error, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_a.csv')

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA   SUCO UVA
# 1                           110 PEPSI LIGHT      PEPSI
# 2                              2L COCA COLA  COCA-COLA
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML     SPRITE
# 4                               AGUA SPRITE     SPRITE

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA         13
# 1                           110 PEPSI LIGHT          8
# 2                              2L COCA COLA          2
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML         10
# 4                               AGUA SPRITE         10

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Lista de Stop Words

# %%
stopwords_arquivo = pd.read_csv('../../stopwords.csv')

lista_stop_words = [ token(word)[0] for word in stopwords_arquivo.stopwords.values ]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome, 
    df.categoria,
    test_size = 0.3, 
    random_state = 42
)

# %% [markdown]
# #### Define CountVectorizer

# %%
count_vectorizer = CountVectorizer(
    tokenizer=token,
    ngram_range=(1,1),
    stop_words=lista_stop_words
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = count_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Busca melhor valor para k

# %%
rmse_val = [] #to store rmse values for different k
best_rmse = 1
k_neighbors = 0
for K in range(40):
    K = K+1
    model = KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train, y_train)  #fit the model
    pred=model.predict(count_vectorizer.transform(X_test).toarray()) #make prediction on test set
    error = sqrt(mean_squared_error(y_test,pred)) #calculate rmse
    if error < best_rmse:
        best_rmse = error
        k_neighbors = K
    rmse_val.append(error) #store rmse values
    
print('RMSE value for k =', k_neighbors ,' is:', best_rmse)
curve = pd.DataFrame(rmse_val) #elbow curve 
curve.plot(figsize=(6,4))
# Out:
# RMSE value for k = 5  is: 0.2955062497849611

# %% [markdown]
# #### Cria um classificador kNN

# %%
knn = KNeighborsClassifier(n_neighbors = k_neighbors)

# %% [markdown]
# #### Treina o classificador

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = knn.predict(count_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 97.7
# precisao: 97.9

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = count_vectorizer.transform([X_test.values[i]])
    pred = knn.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                         Nome     Categoria Original  \
# 0               SUCO AURORA INT UVA BCO 1.5L      SUCO UVA INTEGRAL
# 1               REF LATA FANTA GUARANA 220ML      GUARANA ANTARTICA
# 2                       GV SUCO DE UVA INTEG      SUCO UVA INTEGRAL
# 3        SUCO LARANJA INTEGRAL 300ML NAT ONE  SUCO LARANJA INTEGRAL
# 4                SUCO KAPO LARANJA INF 200ML  SUCO LARANJA INTEGRAL
# 5           REFRIG COCA COLA SPRITE 2L LV PG                 SPRITE
# 6              SUCO PRATS LARANJA INTG 330ML  SUCO LARANJA INTEGRAL
# 7                       SUCO INT LARANJA 1LT  SUCO LARANJA INTEGRAL
# 8                       REFRIG COCA COLA ZER              COCA-COLA
# 9                SUCO E SO LARANJA INT 300ML  SUCO LARANJA INTEGRAL
# 10   SUCO INTEGRAL DE UVA CASA MADEIRA 500ML      SUCO UVA INTEGRAL
# 11         SUCO INTEG UVA 300 ML NOVO CITRUS      SUCO UVA INTEGRAL
# 12                 SUCO TANG UVA INTENSA 25G      SUCO UVA INTEGRAL
# 13                    SUCO PRATS UVA INT 900      SUCO UVA INTEGRAL
# 14                         SUCO DE UVA INTEG      SUCO UVA INTEGRAL
# 15                         SUCO DE UVA INT E      SUCO UVA INTEGRAL
# 16      BEB SUCO UVA AURORA INTEG TINTO 1 5L      SUCO UVA INTEGRAL
# 17             SUCO PRATS LARANJA INTG 900ML  SUCO LARANJA INTEGRAL
# 18     SUCO DOM ELISEO INTEG UVA TINTO 1L GF      SUCO UVA INTEGRAL
# 19     SUCO CASA MADEIRA UVA INTEGRAL GFA 50      SUCO UVA INTEGRAL
# 20          SUCO CASA PERINI INTEG UVA 1L GF      SUCO UVA INTEGRAL
# 21          REF LATA FANTA GUARANA 200ML PET      GUARANA ANTARTICA
# 22  SUCO FRAMB E UVAS BRAN INTEG NOBRE COLHE      SUCO UVA INTEGRAL
# 23        SUCO ALIANCA UVA TINTO INTEG 450ML      SUCO UVA INTEGRAL
#
#               Pred
# 0         SUCO UVA
# 1            FANTA
# 2         SUCO UVA
# 3     SUCO LARANJA
# 4     SUCO LARANJA
# 5        COCA-COLA
# 6     SUCO LARANJA
# 7     SUCO LARANJA
# 8   COCA-COLA ZERO
# 9     SUCO LARANJA
# 10        SUCO UVA
# 11        SUCO UVA
# 12        SUCO UVA
# 13        SUCO UVA
# 14        SUCO UVA
# 15        SUCO UVA
# 16        SUCO UVA
# 17    SUCO LARANJA
# 18        SUCO UVA
# 19        SUCO UVA
# 20        SUCO UVA
# 21           FANTA
# 22        SUCO UVA
# 23        SUCO UVA

# %%
tsne = TSNE().fit_transform(PCA(n_components=25).fit_transform(X_train.todense()))
colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(15)]

# Create plot
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1, 1, 1)

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(tsne[:,0][ix], tsne[:,1][ix], c=colors[g], label = le.inverse_transform([g])[0], s = 8)

plt.title('Matplot scatter plot')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Matriz de Confusão

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_confusion_matrix(
    knn,
    count_vectorizer.transform(X_test).toarray(),
    y_test,
    display_labels=np.unique(le.inverse_transform(y_test)),
    cmap=plt.cm.Blues,
    normalize='true',
    ax=ax,
    xticks_rotation='vertical'
)
