# %% [markdown]
# # k-means
# ### Modelo 03
# - TfidfVectorizer
# - Base A
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_a.csv')

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA   SUCO UVA
# 1                           110 PEPSI LIGHT      PEPSI
# 2                              2L COCA COLA  COCA-COLA
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML     SPRITE
# 4                               AGUA SPRITE     SPRITE

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA         13
# 1                           110 PEPSI LIGHT          8
# 2                              2L COCA COLA          2
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML         10
# 4                               AGUA SPRITE         10

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Lista de Stop Words

# %%
stopwords_arquivo = pd.read_csv('../../stopwords.csv')

lista_stop_words = [ token(word)[0] for word in stopwords_arquivo.stopwords.values ]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome,
    df.categoria,
    test_size = 0.3,
    random_state = 42
)

# %% [markdown]
# #### Define TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(
    tokenizer=token,
    ngram_range=(1,2),
    stop_words=lista_stop_words
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = tfidf_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Cria um classificador k-means

# %%
kmeans = KMeans(
    n_clusters = 15,
    random_state=24
)

# %% [markdown]
# #### Treina o classificador

# %%
kmeans.fit(X_train.toarray(), y_train)
# Out:
# KMeans(n_clusters=15, random_state=24)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = kmeans.predict(tfidf_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 9.0
# precisao: 10.6

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = tfidf_vectorizer.transform([X_test.values[i]])
    pred = kmeans.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                      Nome     Categoria Original  \
# 0                    REF PET SPRITE 1 5LT                 SPRITE
# 1                    GATORADE MORAN MARAC               GATORADE
# 2           REFRIGERANTE SPRITE LIMA O 2L                 SPRITE
# 3            SUCO DEL VALLE UVA SAC 200ML               SUCO UVA
# 4                REFRI COCA COLA LT 350ML              COCA-COLA
# ..                                    ...                    ...
# 964           REFR FANTA GUARANA LT 350ML                  FANTA
# 965                  REFRI ZERO FANTA LAR                  FANTA
# 966                     GUARANA KUAT LATA                   KUAT
# 967  SUCO DE LARANJA INTEGRAL 1LT SUCOESO  SUCO LARANJA INTEGRAL
# 968                  REFRIG CINI 2L LIMAO      CINI REFRIGERANTE
#
#                       Pred
# 0    SUCO LARANJA INTEGRAL
# 1                 SUCO UVA
# 2        GUARANA ANTARTICA
# 3        GUARANA ANTARTICA
# 4        CINI REFRIGERANTE
# ..                     ...
# 964         COCA-COLA ZERO
# 965         COCA-COLA ZERO
# 966                 SPRITE
# 967               GATORADE
# 968                  FANTA
#
# [969 rows x 3 columns]

# %% [markdown]
# #### Gráfico

# %%
model = PCA(n_components=2)
transformed = model.fit_transform(X_train.todense(), y_train)
fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], cmap='tab20b', s=20, label = le.inverse_transform([g])[0])

centers = model.transform(kmeans.cluster_centers_)
plt.scatter(centers[:, 0], centers[:, 1], s=300, c='black', alpha=0.5)

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Termos por cluster

# %%
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = tfidf_vectorizer.get_feature_names()
for i in range(15):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :10]]
    print("Cluster {}: {}".format(i, ', '.join(top_ten_words)))
# Out:
# Cluster 0: prat, suc prat, prat laranj, suc, laranj, laranj prat, suc laranj, integr, prat int, prat integr
# Cluster 1: coc col, col, coc, col zer, zer, col sacuc, sacuc, divers, acuc, col acuc
# Cluster 2: peps, peps col, twist, col, peps twist, peps zer, zer, col twist, cacul, peps cacul
# Cluster 3: fant, fant laranj, fant guar, guar, laranj, fant lar, lar, zer, laranj zer, promoca
# Cluster 4: cin, frambo, cin frambo, cin laranj, gengibirr, cin gengibirr, abacax, laranj, cin guar, lima
# Cluster 5: suc laranj, laranj, suc, larg, suc larg, integr, laranj integr, larg laranj, natur, laranj natur
# Cluster 6: suc, vall, suc vall, laranj, integr, suc integr, tint, maguary, suc maguary, natur
# Cluster 7: kuat, kuat zer, zer, fant laranj, peps col, col zer, sprit orig, kuat guar, antarc guar, suc vall
# Cluster 8: antarc, guar antarc, guar, antarc guar, zer, guar zer, antarc zer, zer antarc, diet, antarc diet
# Cluster 9: skol, skol beat, beat, malt, skol pur, pur, pur malt, sens, beat sens, pilsen
# Cluster 10: guar, kuat, antar, guar kuat, guar antar, kuat guar, guar zer, zer, ant, guar ant
# Cluster 11: brahm, chopp, brahm chopp, brahm zer, brahm extr, extr, zer, lag, malzbi, brahm malzbi
# Cluster 12: sprit, fresh, orig, sprit orig, sprit zer, lemon, sprit lemon, lemon fresh, lima, zer
# Cluster 13: gatorad, gatorad laranj, gatorad lima, isoton, maracuj, isoton gatorad, lima, isot, isot gatorad, gatorad maracuj
# Cluster 14: coc, coc zer, zer, coc coc, col zer, kuat, fant laranj, sprit orig, fresh, kuat guar

# %% [markdown]
# #### Matriz de Confusão

# %%
plot_confusion_matrix(
    conf_mat=confusion_matrix(y_test, Y_Pred),
    figsize=(20, 20),
    show_absolute=False,
    show_normed=True,
    colorbar=True,
    class_names=np.unique(le.inverse_transform(y_test))
)
# Out:
# (<Figure size 1440x1440 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11f5b9990>)
