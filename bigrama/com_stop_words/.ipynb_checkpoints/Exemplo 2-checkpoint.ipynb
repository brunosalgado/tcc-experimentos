# %% [markdown]
# # k-means
# ### Modelo 02
# - CountVectorizer
# - Base B
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_b.csv')

df.head()
# Out:
#                       nome categoria
# 0                   BRAHMA    BRAHMA
# 1             BRAHMA 550ML    BRAHMA
# 2     BRAHMA CERV 350ML LT    BRAHMA
# 3     BRAHMA CERVEJA 350ML    BRAHMA
# 4  BRAHMA CERVEJA 350ML LT    BRAHMA

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                       nome  categoria
# 0                   BRAHMA          0
# 1             BRAHMA 550ML          0
# 2     BRAHMA CERV 350ML LT          0
# 3     BRAHMA CERVEJA 350ML          0
# 4  BRAHMA CERVEJA 350ML LT          0

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Lista de Stop Words

# %%
stopwords_arquivo = pd.read_csv('../../stopwords.csv')

lista_stop_words = [ token(word)[0] for word in stopwords_arquivo.stopwords.values ]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome,
    df.categoria,
    test_size = 0.3,
    random_state = 42
)

# %% [markdown]
# #### Define CountVectorizer

# %%
count_vectorizer = CountVectorizer(
    tokenizer=token,
    ngram_range=(1,2),
    stop_words=lista_stop_words
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = count_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Cria um classificador k-means

# %%
kmeans = KMeans(
    n_clusters = 15,
    random_state=24
)

# %% [markdown]
# #### Treina o classificador

# %%
kmeans.fit(X_train.toarray(), y_train)
# Out:
# KMeans(n_clusters=15, random_state=24)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = kmeans.predict(count_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 2.2
# precisao: 1.6

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = count_vectorizer.transform([X_test.values[i]])
    pred = kmeans.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                    Nome     Categoria Original  \
# 0             CERV SKOL PURO MALTE 473M                   SKOL
# 1                     GUARANA PET 600ML      GUARANA ANTARTICA
# 2                    CERVEJA SKOL 550ML                   SKOL
# 3                  SUCO INT LARANJA 1LT  SUCO LARANJA INTEGRAL
# 4                           GUARANA ANT      GUARANA ANTARTICA
# ..                                  ...                    ...
# 875  SUCO DE LARANJA CAMPO LARGO 900 ML           SUCO LARANJA
# 876                  FANTA LATA LARANJA                  FANTA
# 877                 REFRIG SPRITE 350ML                 SPRITE
# 878                  CERVEJA BRAHMA LAT                 BRAHMA
# 879              CERV BRAHMA CHOPP LATA                 BRAHMA
#
#                       Pred
# 0    SUCO LARANJA INTEGRAL
# 1                    FANTA
# 2        CINI REFRIGERANTE
# 3                    PEPSI
# 4                    FANTA
# ..                     ...
# 875                  PEPSI
# 876                   SKOL
# 877         COCA-COLA ZERO
# 878      CINI REFRIGERANTE
# 879      CINI REFRIGERANTE
#
# [880 rows x 3 columns]

# %% [markdown]
# #### Gráfico

# %%
model = PCA(n_components=2)
transformed = model.fit_transform(X_train.todense(), y_train)
fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], cmap='tab20b', s=20, label = le.inverse_transform([g])[0])

centers = model.transform(kmeans.cluster_centers_)
plt.scatter(centers[:, 0], centers[:, 1], s=300, c='black', alpha=0.5)

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Termos por cluster

# %%
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = count_vectorizer.get_feature_names()
for i in range(15):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :10]]
    print("Cluster {}: {}".format(i, ', '.join(top_ten_words)))
# Out:
# Cluster 0: cin, frambo, laranj, cin frambo, abacax, cin laranj, zer, cin abacax, cin gengibirr, gengibirr
# Cluster 1: gatorad, brahm, skol, kuat, fant, zer, coc, skol beat, beat, chopp
# Cluster 2: col, zer, coc, coc col, col zer, sacuc zer, sacuc, col sacuc, co, zer divers
# Cluster 3: sprit, fresh, orig, sprit orig, lima, sprit fresh, zer, acuc, lemon, sprit zer
# Cluster 4: guar, kuat, antarc, zer, guar kuat, guar antarc, fant, fant guar, antar, kuat guar
# Cluster 5: suc, laranj integr, integr, laranj, suc laranj, larg, suc larg, larg laranj, prat, one
# Cluster 6: col, coc, coc col, col sacuc, sacuc, acuc, col acuc, col lfant, lfant, agu
# Cluster 7: vall, suc, suc vall, laranj, integr, vall laranj, laranj integr, fresh, vall fresh, vall frut
# Cluster 8: suc, laranj, suc laranj, prat, natur, int, laranj int, suc prat, prat laranj, larg
# Cluster 9: fant, laranj, fant laranj, zer, laranj zer, light, acuc, laranj light, zer acuc, coc
# Cluster 10: suc, larg, int, suc larg, tint, suc int, aur, suc aur, intg, suc intg
# Cluster 11: suc, integr, suc integr, larg, suc larg, larg integr, tint, tint integr, laranj, integr laranj
# Cluster 12: skol, pur, skol pur, malt, pur malt, x, malt x, ma, pur ma, brahm
# Cluster 13: peps, peps twist, twist, coc col, antarc, vall, zro, peps zer, ex, pasc
# Cluster 14: peps, col, peps col, zer, peps zer, twist, col twist, promoca, col zer, tw

# %% [markdown]
# #### Matriz de Confusão

# %%
plot_confusion_matrix(
    conf_mat=confusion_matrix(y_test, Y_Pred),
    figsize=(20, 20),
    show_absolute=False,
    show_normed=True,
    colorbar=True,
    class_names=np.unique(le.inverse_transform(y_test))
)
# Out:
# (<Figure size 1440x1440 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x127393690>)
