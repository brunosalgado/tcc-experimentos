# %% [markdown]
# # K-Nearest Neighbors
# ### Modelo 05
# - CountVectorizer
# - Base A
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, mean_squared_error, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_a.csv')

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA   SUCO UVA
# 1                           110 PEPSI LIGHT      PEPSI
# 2                              2L COCA COLA  COCA-COLA
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML     SPRITE
# 4                               AGUA SPRITE     SPRITE

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA         13
# 1                           110 PEPSI LIGHT          8
# 2                              2L COCA COLA          2
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML         10
# 4                               AGUA SPRITE         10

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome, 
    df.categoria,
    test_size = 0.3, 
    random_state = 42
)

# %% [markdown]
# #### Define CountVectorizer

# %%
count_vectorizer = CountVectorizer(
    tokenizer=token,
    ngram_range=(1,2)
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = count_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Busca melhor valor para k

# %%
best_rmse = 1
k_neighbors = 0

k_range = range(1, 31)
k_scores = []
for k in k_range:
    model = KNeighborsClassifier(n_neighbors=k)
    loss = abs(cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error'))
    k_scores.append(loss.mean())
    if loss.mean() < best_rmse:
        best_rmse = loss.mean()
        k_neighbors = k
plt.plot(k_range, k_scores)
plt.xlabel('Valor de K')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# #### Cria um classificador kNN

# %%
knn = KNeighborsClassifier(n_neighbors = k_neighbors)

# %% [markdown]
# #### Treina o classificador

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=22)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = knn.predict(count_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 95.6
# precisao: 96.1

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = count_vectorizer.transform([X_test.values[i]])
    pred = knn.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                              Nome     Categoria Original  \
# 0             SUCO E SO LARANJA INTEGRAL GF 300ML  SUCO LARANJA INTEGRAL
# 1            SUCO DE LARANJA INTEGRAL PRATS 900ML  SUCO LARANJA INTEGRAL
# 2                    SUCO AURORA INT UVA BCO 1.5L      SUCO UVA INTEGRAL
# 3                            REFRI COCA COLA ZERO         COCA-COLA ZERO
# 4                  SUCO INTEGRAL DE LARANJA 300ML  SUCO LARANJA INTEGRAL
# 5                    REF LATA FANTA GUARANA 220ML      GUARANA ANTARTICA
# 6                            REFR GUARANA KUAT 35                   KUAT
# 7                            GV SUCO DE UVA INTEG      SUCO UVA INTEGRAL
# 8             SUCO LARANJA INTEGRAL 300ML NAT ONE  SUCO LARANJA INTEGRAL
# 9                     SUCO KAPO LARANJA INF 200ML  SUCO LARANJA INTEGRAL
# 10                       SUCO UVA INTEGRAL 345 ML      SUCO UVA INTEGRAL
# 11               REFRIG COCA COLA SPRITE 2L LV PG                 SPRITE
# 12          SUCO SALTON UVA TINTO INTEGRAL GFA 1.      SUCO UVA INTEGRAL
# 13               SUCO CAMPO LARGO UVA INTEGRAL 90      SUCO UVA INTEGRAL
# 14       SUCO DE LARANJA VIVA FELIZ 330ML INTEGRA  SUCO LARANJA INTEGRAL
# 15                  SUCO PRATS LARANJA INTG 330ML  SUCO LARANJA INTEGRAL
# 16                           COCA COLA 200ML ZERO         COCA-COLA ZERO
# 17                   SUCO DE UVA INTEGRAL 1 LITRO      SUCO UVA INTEGRAL
# 18  SUCO DE UVA TINTO INTEGRAL CAMPO LARGO 1 350L      SUCO UVA INTEGRAL
# 19                              COCA COLA 1L ZERO         COCA-COLA ZERO
# 20                           SUCO INT LARANJA 1LT  SUCO LARANJA INTEGRAL
# 21                           REFRIG COCA COLA ZER              COCA-COLA
# 22                    SUCO E SO LARANJA INT 300ML  SUCO LARANJA INTEGRAL
# 23                              SUCO INTEGRAL UVA      SUCO UVA INTEGRAL
# 24              SUCO INTEG UVA 300 ML NOVO CITRUS      SUCO UVA INTEGRAL
# 25                    SUCO UVA PRIMA DUO INTEGRAL      SUCO UVA INTEGRAL
# 26                      SUCO TANG UVA INTENSA 25G      SUCO UVA INTEGRAL
# 27                         SUCO PRATS UVA INT 900      SUCO UVA INTEGRAL
# 28                           CINI MIX GUARANA ACA      CINI REFRIGERANTE
# 29                              SUCO DE UVA INTEG      SUCO UVA INTEGRAL
# 30                         REF COCA COLA 1 L ZERO         COCA-COLA ZERO
# 31          SUCO SALTON UVA TINTO INTEGRAL GFA 50      SUCO UVA INTEGRAL
# 32       BELLA VITTA SUCO UVA TINTO INTEGRAL 1 5L      SUCO UVA INTEGRAL
# 33                              SUCO DE UVA INT E      SUCO UVA INTEGRAL
# 34              SUCO LIFE LARANJA INTEGRAL GFA 5L  SUCO LARANJA INTEGRAL
# 35           BEB SUCO UVA AURORA INTEG TINTO 1 5L      SUCO UVA INTEGRAL
# 36                  SUCO PRATS LARANJA INTG 900ML  SUCO LARANJA INTEGRAL
# 37          SUCO DOM ELISEO INTEG UVA TINTO 1L GF      SUCO UVA INTEGRAL
# 38           SUCO DE LARANJA INTEGRAL PRATS 1 7 L  SUCO LARANJA INTEGRAL
# 39          SUCO SUCO E SO LARANJA INTEGRAL 300ML  SUCO LARANJA INTEGRAL
# 40        SUCO NATURAL ONE INTEGRAL LARANJA 900ML  SUCO LARANJA INTEGRAL
# 41               SUCO CASA PERINI INTEG UVA 1L GF      SUCO UVA INTEGRAL
# 42          SUCO CAMPO LARGO LARANJA INT RESF 900  SUCO LARANJA INTEGRAL
# 43               REF LATA FANTA GUARANA 200ML PET      GUARANA ANTARTICA
# 44       SUCO FRAMB E UVAS BRAN INTEG NOBRE COLHE      SUCO UVA INTEGRAL
# 45             SUCO ALIANCA UVA TINTO INTEG 450ML      SUCO UVA INTEGRAL
# 46           SUCO DE LARANJA INTEGRAL 1LT SUCOESO  SUCO LARANJA INTEGRAL
#
#                  Pred
# 0        SUCO LARANJA
# 1        SUCO LARANJA
# 2            SUCO UVA
# 3           COCA-COLA
# 4        SUCO LARANJA
# 5               FANTA
# 6   GUARANA ANTARTICA
# 7            SUCO UVA
# 8        SUCO LARANJA
# 9        SUCO LARANJA
# 10           SUCO UVA
# 11          COCA-COLA
# 12           SUCO UVA
# 13           SUCO UVA
# 14       SUCO LARANJA
# 15       SUCO LARANJA
# 16          COCA-COLA
# 17           SUCO UVA
# 18           SUCO UVA
# 19          COCA-COLA
# 20       SUCO LARANJA
# 21     COCA-COLA ZERO
# 22       SUCO LARANJA
# 23           SUCO UVA
# 24           SUCO UVA
# 25           SUCO UVA
# 26           SUCO UVA
# 27           SUCO UVA
# 28  GUARANA ANTARTICA
# 29           SUCO UVA
# 30          COCA-COLA
# 31           SUCO UVA
# 32           SUCO UVA
# 33           SUCO UVA
# 34       SUCO LARANJA
# 35           SUCO UVA
# 36       SUCO LARANJA
# 37           SUCO UVA
# 38       SUCO LARANJA
# 39       SUCO LARANJA
# 40       SUCO LARANJA
# 41           SUCO UVA
# 42       SUCO LARANJA
# 43              FANTA
# 44           SUCO UVA
# 45           SUCO UVA
# 46       SUCO LARANJA

# %%
model = TSNE(n_components=2, init='pca', random_state=0)
transformed = model.fit_transform(X_train.todense())

fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], c=[plt.cm.tab20b(float(g)/15)], s=20, label = le.inverse_transform([g])[0])

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Matriz de Confusão

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_confusion_matrix(
    knn,
    count_vectorizer.transform(X_test).toarray(),
    y_test,
    display_labels=np.unique(le.inverse_transform(y_test)),
    cmap=plt.cm.Blues,
    normalize='true',
    ax=ax,
    xticks_rotation='vertical'
)
