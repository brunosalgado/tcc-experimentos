# %% [markdown]
# # k-means
# ### Modelo 04
# - TfidfVectorizer
# - Base B
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_b.csv')

df.head()
# Out:
#                       nome categoria
# 0                   BRAHMA    BRAHMA
# 1             BRAHMA 550ML    BRAHMA
# 2     BRAHMA CERV 350ML LT    BRAHMA
# 3     BRAHMA CERVEJA 350ML    BRAHMA
# 4  BRAHMA CERVEJA 350ML LT    BRAHMA

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                       nome  categoria
# 0                   BRAHMA          0
# 1             BRAHMA 550ML          0
# 2     BRAHMA CERV 350ML LT          0
# 3     BRAHMA CERVEJA 350ML          0
# 4  BRAHMA CERVEJA 350ML LT          0

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome,
    df.categoria,
    test_size = 0.3,
    random_state = 42
)

# %% [markdown]
# #### Define TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(
    tokenizer=token,
    ngram_range=(1,2)
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = tfidf_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Cria um classificador k-means

# %%
kmeans = KMeans(
    n_clusters = 15,
    random_state=24
)

# %% [markdown]
# #### Treina o classificador

# %%
kmeans.fit(X_train.toarray(), y_train)
# Out:
# KMeans(n_clusters=15, random_state=24)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = kmeans.predict(tfidf_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 3.1
# precisao: 2.6

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = tfidf_vectorizer.transform([X_test.values[i]])
    pred = kmeans.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                    Nome Categoria Original               Pred
# 0             CERV SKOL PURO MALTE 473M               SKOL           SUCO UVA
# 1                     GUARANA PET 600ML  GUARANA ANTARTICA               SKOL
# 2                    CERVEJA SKOL 550ML               SKOL           SUCO UVA
# 3             FANTA GUARANA LATA 350 ML              FANTA     COCA-COLA ZERO
# 4                           GUARANA ANT  GUARANA ANTARTICA               SKOL
# ..                                  ...                ...                ...
# 867  SUCO DE LARANJA CAMPO LARGO 900 ML       SUCO LARANJA              FANTA
# 868                  FANTA LATA LARANJA              FANTA  GUARANA ANTARTICA
# 869                 REFRIG SPRITE 350ML             SPRITE              PEPSI
# 870                  CERVEJA BRAHMA LAT             BRAHMA       SUCO LARANJA
# 871              CERV BRAHMA CHOPP LATA             BRAHMA       SUCO LARANJA
#
# [872 rows x 3 columns]

# %% [markdown]
# #### Gráfico

# %%
model = PCA(n_components=2)
transformed = model.fit_transform(X_train.todense(), y_train)
fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], cmap='tab20b', s=20, label = le.inverse_transform([g])[0])

centers = model.transform(kmeans.cluster_centers_)
plt.scatter(centers[:, 0], centers[:, 1], s=300, c='black', alpha=0.5)

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Termos por cluster

# %%
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = tfidf_vectorizer.get_feature_names()
for i in range(15):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :10]]
    print("Cluster {}: {}".format(i, ', '.join(top_ten_words)))
# Out:
# Cluster 0: de, suc de, suc, de laranj, integr, de uva, laranj, laranj integr, uva, uva integr
# Cluster 1: col zer, zer, coc, coc col, col, zer ml, refr coc, ml, zer lt, refr
# Cluster 2: cin, refrig cin, l, refrig, frambo, refr cin, cin laranj, abacax, refr, cin frambo
# Cluster 3: lat, lat ml, ml, coc, zer lat, col lat, zer, col, coc col, skol lat
# Cluster 4: camp, camp larg, larg, suc camp, suc, larg uva, integr, uva, laranj, larg laranj
# Cluster 5: kuat, guar, guar kuat, kuat ml, kuat guar, refrig kuat, kuat zer, refr kuat, ml, l
# Cluster 6: fant, fant laranj, fant guar, refrig fant, refr fant, ml, laranj, refrig, guar, fant uva
# Cluster 7: gatorad, ml, gatorad ml, maracuj, beb, isoton, gatorad uva, isot, isot gatorad, beb gatorad
# Cluster 8: sprit, refr sprit, refrig sprit, sprit ml, ml, refr, refrig, sprit lt, lt, fresh
# Cluster 9: guar, antarc, antar, guar antarc, guar antar, refr guar, l, refr, antarc guar, zer
# Cluster 10: peps, peps col, refrig peps, col, refr peps, refrig, l, twist, refr, peps ml
# Cluster 11: brahm, cerv, cerv brahm, cervej brahm, cervej, chopp, brahm chopp, ml, brahm ml, extr
# Cluster 12: suc, uva, laranj, suc laranj, suc uva, integr, del, vall, del vall, ml
# Cluster 13: skol, cerv skol, cerv, beat, cervej skol, skol beat, cervej, ml, pur, malt
# Cluster 14: coc col, coc, col, col ml, refr coc, ml, refrig coc, col pet, pet, refr

# %% [markdown]
# #### Matriz de Confusão

# %%
plot_confusion_matrix(
    conf_mat=confusion_matrix(y_test, Y_Pred),
    figsize=(20, 20),
    show_absolute=False,
    show_normed=True,
    colorbar=True,
    class_names=np.unique(le.inverse_transform(y_test))
)
# Out:
# (<Figure size 1440x1440 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x124d1ae50>)
