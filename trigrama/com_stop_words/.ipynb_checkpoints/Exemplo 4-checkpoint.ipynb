# %% [markdown]
# # k-means
# ### Modelo 04
# - TfidfVectorizer
# - Base B
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_b.csv')

df.head()
# Out:
#                       nome categoria
# 0                   BRAHMA    BRAHMA
# 1             BRAHMA 550ML    BRAHMA
# 2     BRAHMA CERV 350ML LT    BRAHMA
# 3     BRAHMA CERVEJA 350ML    BRAHMA
# 4  BRAHMA CERVEJA 350ML LT    BRAHMA

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                       nome  categoria
# 0                   BRAHMA          0
# 1             BRAHMA 550ML          0
# 2     BRAHMA CERV 350ML LT          0
# 3     BRAHMA CERVEJA 350ML          0
# 4  BRAHMA CERVEJA 350ML LT          0

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Lista de Stop Words

# %%
stopwords_arquivo = pd.read_csv('../../stopwords.csv')

lista_stop_words = [ token(word)[0] for word in stopwords_arquivo.stopwords.values ]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome,
    df.categoria,
    test_size = 0.3,
    random_state = 42
)

# %% [markdown]
# #### Define TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(
    tokenizer=token,
    ngram_range=(1,3),
    stop_words=lista_stop_words
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = tfidf_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Cria um classificador k-means

# %%
kmeans = KMeans(
    n_clusters = 15,
    random_state=24
)

# %% [markdown]
# #### Treina o classificador

# %%
kmeans.fit(X_train.toarray(), y_train)
# Out:
# KMeans(n_clusters=15, random_state=24)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = kmeans.predict(tfidf_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 0.6
# precisao: 0.1

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = tfidf_vectorizer.transform([X_test.values[i]])
    pred = kmeans.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                    Nome     Categoria Original  \
# 0             CERV SKOL PURO MALTE 473M                   SKOL
# 1                     GUARANA PET 600ML      GUARANA ANTARTICA
# 2                    CERVEJA SKOL 550ML                   SKOL
# 3             FANTA GUARANA LATA 350 ML                  FANTA
# 4                  SUCO INT LARANJA 1LT  SUCO LARANJA INTEGRAL
# ..                                  ...                    ...
# 890  SUCO DE LARANJA CAMPO LARGO 900 ML           SUCO LARANJA
# 891                  FANTA LATA LARANJA                  FANTA
# 892                 REFRIG SPRITE 350ML                 SPRITE
# 893                  CERVEJA BRAHMA LAT                 BRAHMA
# 894              CERV BRAHMA CHOPP LATA                 BRAHMA
#
#                   Pred
# 0    SUCO UVA INTEGRAL
# 1                 SKOL
# 2               SPRITE
# 3             GATORADE
# 4            COCA-COLA
# ..                 ...
# 890          COCA-COLA
# 891           GATORADE
# 892              FANTA
# 893  GUARANA ANTARTICA
# 894  GUARANA ANTARTICA
#
# [895 rows x 3 columns]

# %% [markdown]
# #### Gráfico

# %%
model = PCA(n_components=2)
transformed = model.fit_transform(X_train.todense(), y_train)
fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], cmap='tab20b', s=20, label = le.inverse_transform([g])[0])

centers = model.transform(kmeans.cluster_centers_)
plt.scatter(centers[:, 0], centers[:, 1], s=300, c='black', alpha=0.5)

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Termos por cluster

# %%
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = tfidf_vectorizer.get_feature_names()
for i in range(15):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :10]]
    print("Cluster {}: {}".format(i, ', '.join(top_ten_words)))
# Out:
# Cluster 0: kuat, kuat guar, kuat zer, zer, guar, kuat guar zer, guar zer, gua, gua kuat, guaran kuat
# Cluster 1: coc, coc zer, zer, coc zr, zr, skol, suc laranj, brahm chopp, twist, suc laranj integr
# Cluster 2: suc, laranj, integr, suc laranj, suc integr, laranj integr, suc laranj integr, larg, vall, suc larg
# Cluster 3: peps, peps col, col, twist, peps twist, peps zer, zer, col twist, peps col twist, peps col zer
# Cluster 4: sprit, orig, sprit orig, fresh, sprit zer, sprit fresh, lima, sprit lima, lemon, acuc
# Cluster 5: fant, fant laranj, fant guar, laranj, guar, fant lar, lar, fant lja, lja, fant laranj zer
# Cluster 6: brahm, chopp, brahm chopp, extr, brahm extr, brahm zer, malzbi, lag, zer, brahm extr lag
# Cluster 7: coc col, coc, col, coc col sacuc, col sacuc, sacuc, sprit, peps, gatorad, peps col
# Cluster 8: coc col zer, col zer, coc col, zer, coc, col, zer divers, col zer divers, divers, col zer acuc
# Cluster 9: guar, guar kuat, kuat, antar, guar antar, ant, zer, guar zer, guar ant, antarct
# Cluster 10: skol, skol beat, beat, sens, skol pilsen, beat sens, skol beat sens, pilsen, skol beat sem, beat sem
# Cluster 11: cin, frambo, cin laranj, cin frambo, abacax, cin abacax, laranj, cin gengibirr, gengibirr, framb
# Cluster 12: antarc, guar antarc, guar, antarc guar, guar antarc zer, antarc zer, zer, guar zer, antarc guar zer, zer antarc
# Cluster 13: gatorad, maracuj, isot, isot gatorad, gatorad laranj, isoton, gatorad maracuj, tangerin, gatorad lima, isoton gatorad
# Cluster 14: skol pur, pur, skol pur malt, pur malt, malt, skol, malt x, pur malt x, x, pur ma

# %% [markdown]
# #### Matriz de Confusão

# %%
plot_confusion_matrix(
    conf_mat=confusion_matrix(y_test, Y_Pred),
    figsize=(20, 20),
    show_absolute=False,
    show_normed=True,
    colorbar=True,
    class_names=np.unique(le.inverse_transform(y_test))
)
# Out:
# (<Figure size 1440x1440 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11885e310>)
