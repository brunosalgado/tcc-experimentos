# %% [markdown]
# # K-Nearest Neighbors
# ### Modelo 08
# - TfidfVectorizer
# - Base B
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, mean_squared_error, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_b.csv')

df.head()
# Out:
#                       nome categoria
# 0                   BRAHMA    BRAHMA
# 1             BRAHMA 550ML    BRAHMA
# 2     BRAHMA CERV 350ML LT    BRAHMA
# 3     BRAHMA CERVEJA 350ML    BRAHMA
# 4  BRAHMA CERVEJA 350ML LT    BRAHMA

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                       nome  categoria
# 0                   BRAHMA          0
# 1             BRAHMA 550ML          0
# 2     BRAHMA CERV 350ML LT          0
# 3     BRAHMA CERVEJA 350ML          0
# 4  BRAHMA CERVEJA 350ML LT          0

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Lista de Stop Words

# %%
stopwords_arquivo = pd.read_csv('../../stopwords.csv')

lista_stop_words = [ token(word)[0] for word in stopwords_arquivo.stopwords.values ]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome, 
    df.categoria,
    test_size = 0.3, 
    random_state = 42
)

# %% [markdown]
# #### Define TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(
    tokenizer=token,
    ngram_range=(1,3),
    stop_words=lista_stop_words
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = tfidf_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Busca melhor valor para k

# %%
best_rmse = 1
k_neighbors = 0

k_range = range(1, 31)
k_scores = []
for k in k_range:
    model = KNeighborsClassifier(n_neighbors=k)
    loss = abs(cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error'))
    k_scores.append(loss.mean())
    if loss.mean() < best_rmse:
        best_rmse = loss.mean()
        k_neighbors = k
plt.plot(k_range, k_scores)
plt.xlabel('Valor de K')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# #### Cria um classificador kNN

# %%
knn = KNeighborsClassifier(n_neighbors = k_neighbors)

# %% [markdown]
# #### Treina o classificador

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=27)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = knn.predict(tfidf_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 93.8
# precisao: 94.5

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = tfidf_vectorizer.transform([X_test.values[i]])
    pred = knn.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                            Nome     Categoria Original  \
# 0                          SUCO INT LARANJA 1LT  SUCO LARANJA INTEGRAL
# 1                IFOOD SUCO DE LARANJA INTG 300  SUCO LARANJA INTEGRAL
# 2                         COCA ZERO PET 2L 6 UN         COCA-COLA ZERO
# 3                               COCA CO ZERO 1L         COCA-COLA ZERO
# 4            SUCO DEL VALLE FRESH LARANJA 400ML           SUCO LARANJA
# 5           SUCO CAMPO LARGO LARANJA GFA 1.350L           SUCO LARANJA
# 6         SUCO ALIANCA UVA BRANCO INTEG GFA 1.5      SUCO UVA INTEGRAL
# 7     REFRIG COCA COLA SACUCAR LT 220ML C6 ZERO         COCA-COLA ZERO
# 8        SUCO DEL VALLE FRESH UVA INTEGRAL 1 5L      SUCO UVA INTEGRAL
# 9                             COCA ZERO 200 MLS         COCA-COLA ZERO
# 10                   REFRIG CINI GUARANA PET 2L      CINI REFRIGERANTE
# 11                FF SUCO SELECT UVA INTG 400ML      SUCO UVA INTEGRAL
# 12                            SUCO DE UVA INTEG      SUCO UVA INTEGRAL
# 13                REFRIGERANTE CINI GUARANA 2LT      CINI REFRIGERANTE
# 14                     SUCO PRATS UVA PET 900ML               SUCO UVA
# 15          SUCO CAMPO LARGO UVA INTEGRAL 200ML      SUCO UVA INTEGRAL
# 16                              COCA ZERO P ALC         COCA-COLA ZERO
# 17           SUCO DEL VALLE 100 UVA INTEGRAL 1L      SUCO UVA INTEGRAL
# 18                          REFRI COCA ZERO 1LT         COCA-COLA ZERO
# 19                     REFRI CINI GUARANA 600ML      CINI REFRIGERANTE
# 20                           REFRI COCA ZERO 2L         COCA-COLA ZERO
# 21                        REFRI CINI 2L GUARANA      CINI REFRIGERANTE
# 22  SUCO CAMPO LARGO GOL LARANJA INTEGRAL 250ML  SUCO LARANJA INTEGRAL
# 23      SUCO CAMPO LARGO GOL UVA INTEGRAL 250ML      SUCO UVA INTEGRAL
# 24     SUCO DE LARANJA VIVA FELIZ 330ML INTEGRA  SUCO LARANJA INTEGRAL
# 25                           C9 COCA ZERO 220ML         COCA-COLA ZERO
# 26                         UVA INTG SUCO 300 ML      SUCO UVA INTEGRAL
# 27               IFOOD SUCO LARANJA INTG 900 ML  SUCO LARANJA INTEGRAL
# 28                       REFRIG CINI GUARANA 2L      CINI REFRIGERANTE
# 29                         SUCO UVA TINTO INT P      SUCO UVA INTEGRAL
# 30      SUCO CAMPO LARGO INTEGRAL LARANJA 250ML  SUCO LARANJA INTEGRAL
# 31                       REFRIG CINI GUARANA AB      CINI REFRIGERANTE
# 32         G SUCO DEL VALLE 1L LARANJA INTEGRAL  SUCO LARANJA INTEGRAL
# 33                        SUCO CAMP LAR LARANJA           SUCO LARANJA
# 34                             COCA ZERO 220 ML         COCA-COLA ZERO
# 35                    REFRIGERANTE CINI GUARANA      CINI REFRIGERANTE
# 36        SUCO DEL VALLE FRESH LARANJA INTEGRAL  SUCO LARANJA INTEGRAL
# 37          SUCO CAMPO LARGO COLD 900ML LARANJA           SUCO LARANJA
# 38                          SUCO C LAR UVA 1 5L               SUCO UVA
# 39             SUCO CAMPO LARGO UVA INTEGRAL 90      SUCO UVA INTEGRAL
# 40                    SUCO TANG UVA INTENSA 25G      SUCO UVA INTEGRAL
# 41        SUCO PANIZZON UVA BRANCO INTEG GFA 1.      SUCO UVA INTEGRAL
# 42               REFRIG FANTA SPRITE KUAT 600ML                   KUAT
# 43           SUCO CAMPO LARGO LARANJA GFA 250ML           SUCO LARANJA
# 44                          SUCO DE LARANJA INT  SUCO LARANJA INTEGRAL
# 45       SUCO DEL VALLE FRESH LARANJA PET 400ML           SUCO LARANJA
# 46          SUCO CAMPO LARGO UVA INTEGRAL 900ML      SUCO UVA INTEGRAL
# 47          SUCO INTEGRAL DE LARANJA SUCOESO 1L  SUCO LARANJA INTEGRAL
# 48           SUCO ALIANCA UVA TINTO INTEG 450ML      SUCO UVA INTEGRAL
# 49            SUCO NATURAL ONE UVA E MACA 300ML               SUCO UVA
# 50                 REF DES.CINI WINI 2L GUARANA      CINI REFRIGERANTE
# 51     SUCO NATURAL ONE SPECIAL BLEND UVA 900ML               SUCO UVA
# 52                         REFRIG COCA COLA ZER              COCA-COLA
# 53                            COLA COCA 1L ZERO         COCA-COLA ZERO
# 54            SUCO DEL VALLE FRESH LARANJA 1 5L           SUCO LARANJA
# 55                         REF COCA ZERO LT 350         COCA-COLA ZERO
#
#                      Pred
# 0       SUCO UVA INTEGRAL
# 1            SUCO LARANJA
# 2               COCA-COLA
# 3               COCA-COLA
# 4                SUCO UVA
# 5   SUCO LARANJA INTEGRAL
# 6                SUCO UVA
# 7               COCA-COLA
# 8                SUCO UVA
# 9               COCA-COLA
# 10      GUARANA ANTARTICA
# 11               SUCO UVA
# 12               SUCO UVA
# 13      GUARANA ANTARTICA
# 14           SUCO LARANJA
# 15               SUCO UVA
# 16              COCA-COLA
# 17               SUCO UVA
# 18              COCA-COLA
# 19      GUARANA ANTARTICA
# 20              COCA-COLA
# 21      GUARANA ANTARTICA
# 22               SUCO UVA
# 23               SUCO UVA
# 24           SUCO LARANJA
# 25              COCA-COLA
# 26               SUCO UVA
# 27           SUCO LARANJA
# 28      GUARANA ANTARTICA
# 29               SUCO UVA
# 30               SUCO UVA
# 31      GUARANA ANTARTICA
# 32               SUCO UVA
# 33                  FANTA
# 34              COCA-COLA
# 35      GUARANA ANTARTICA
# 36               SUCO UVA
# 37               SUCO UVA
# 38                  FANTA
# 39               SUCO UVA
# 40               SUCO UVA
# 41               SUCO UVA
# 42                  FANTA
# 43  SUCO LARANJA INTEGRAL
# 44           SUCO LARANJA
# 45               SUCO UVA
# 46               SUCO UVA
# 47      SUCO UVA INTEGRAL
# 48               SUCO UVA
# 49           SUCO LARANJA
# 50      GUARANA ANTARTICA
# 51           SUCO LARANJA
# 52         COCA-COLA ZERO
# 53              COCA-COLA
# 54               SUCO UVA
# 55              COCA-COLA

# %%
model = TSNE(n_components=2, init='pca', random_state=0)
transformed = model.fit_transform(X_train.todense())

fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], c=[plt.cm.tab20b(float(g)/15)], s=20, label = le.inverse_transform([g])[0])

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Matriz de Confusão

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_confusion_matrix(
    knn,
    tfidf_vectorizer.transform(X_test).toarray(),
    y_test,
    display_labels=np.unique(le.inverse_transform(y_test)),
    cmap=plt.cm.Blues,
    normalize='true',
    ax=ax,
    xticks_rotation='vertical'
)
