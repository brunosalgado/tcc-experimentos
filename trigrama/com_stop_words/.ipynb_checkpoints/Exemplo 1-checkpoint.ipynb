# %% [markdown]
# # k-means
# ### Modelo 01
# - CountVectorizer
# - Base A
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_a.csv')

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA   SUCO UVA
# 1                           110 PEPSI LIGHT      PEPSI
# 2                              2L COCA COLA  COCA-COLA
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML     SPRITE
# 4                               AGUA SPRITE     SPRITE

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA         13
# 1                           110 PEPSI LIGHT          8
# 2                              2L COCA COLA          2
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML         10
# 4                               AGUA SPRITE         10

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Lista de Stop Words

# %%
stopwords_arquivo = pd.read_csv('../../stopwords.csv')

lista_stop_words = [ token(word)[0] for word in stopwords_arquivo.stopwords.values ]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome,
    df.categoria,
    test_size = 0.3,
    random_state = 42
)

# %% [markdown]
# #### Define CountVectorizer

# %%
count_vectorizer = CountVectorizer(
    tokenizer=token,
    ngram_range=(1,3),
    stop_words=lista_stop_words
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = count_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Cria um classificador k-means

# %%
kmeans = KMeans(
    n_clusters = 15,
    random_state=24
)

# %% [markdown]
# #### Treina o classificador

# %%
kmeans.fit(X_train.toarray(), y_train)
# Out:
# KMeans(n_clusters=15, random_state=24)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = kmeans.predict(count_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 0.8
# precisao: 7.5

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = count_vectorizer.transform([X_test.values[i]])
    pred = kmeans.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                       Nome     Categoria Original  \
# 0          CERV SKOL BEATS SENSES LN 313ML                   SKOL
# 1                     REF PET SPRITE 1 5LT                 SPRITE
# 2                     GATORADE MORAN MARAC               GATORADE
# 3            REFRIGERANTE SPRITE LIMA O 2L                 SPRITE
# 4             SUCO DEL VALLE UVA SAC 200ML               SUCO UVA
# ...                                    ...                    ...
# 1052           REFR FANTA GUARANA LT 350ML                  FANTA
# 1053                  REFRI ZERO FANTA LAR                  FANTA
# 1054                     GUARANA KUAT LATA                   KUAT
# 1055  SUCO DE LARANJA INTEGRAL 1LT SUCOESO  SUCO LARANJA INTEGRAL
# 1056                  REFRIG CINI 2L LIMAO      CINI REFRIGERANTE
#
#                    Pred
# 0          SUCO LARANJA
# 1                BRAHMA
# 2                SPRITE
# 3                BRAHMA
# 4                  SKOL
# ...                 ...
# 1052  CINI REFRIGERANTE
# 1053          COCA-COLA
# 1054             BRAHMA
# 1055               SKOL
# 1056             BRAHMA
#
# [1057 rows x 3 columns]

# %% [markdown]
# #### Gráfico

# %%
model = PCA(n_components=2)
transformed = model.fit_transform(X_train.todense(), y_train)
fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], cmap='tab20b', s=20, label = le.inverse_transform([g])[0])

centers = model.transform(kmeans.cluster_centers_)
plt.scatter(centers[:, 0], centers[:, 1], s=300, c='black', alpha=0.5)

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Termos por cluster

# %%
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = count_vectorizer.get_feature_names()
for i in range(15):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :10]]
    print("Cluster {}: {}".format(i, ', '.join(top_ten_words)))
# Out:
# Cluster 0: cin, sprit, kuat, guar, zer, coc, frambo, lima, cin frambo, laranj
# Cluster 1: guar, fant, fant guar, zer, guar zer, fant guar zer, promoca, fant guar promoca, guar promoca, guar fant
# Cluster 2: fant, laranj, fant laranj, fant lar, lar, zer, lja, laranj zer, fant laranj zer, fant lja
# Cluster 3: skol, malt, pur, skol pur, pur malt, skol pur malt, pilsen, skol pilsen, promoca, pilsen promoca
# Cluster 4: prat, suc, suc prat, laranj, suc prat laranj, prat laranj, suc laranj, suc laranj prat, laranj prat, integr
# Cluster 5: brahm, chopp, brahm chopp, brahm extr, extr, zer, lag, brahm zer, malzbi, extr lag
# Cluster 6: ant, guar, guar ant, ant guar, guar z, guar ant peps, z, ant guar z, ant peps, peps
# Cluster 7: coc, coc col, col, zer, coc col zer, col zer, sacuc, col sacuc, coc col sacuc, acuc
# Cluster 8: guar, zer, guar zer, antarc, antarc guar, antarc guar zer, guar zer antarc, zer antarc, antar guar, antar
# Cluster 9: suc, laranj, suc laranj, integr, larg, vall, suc larg, suc vall, natur, tint
# Cluster 10: gatorad, isoton, maracuj, isoton gatorad, lima, isot, gatorad lima, laranj, gatorad laranj, isot gatorad
# Cluster 11: skol, skol beat, beat, sens, beat sens, skol beat sens, gin tonic, tonic, skol beat gin, beat gin
# Cluster 12: antar, guar, guar antar, zer, antar guar, antar zer, guar antar zer, diet, guar antar diet, guar antar z
# Cluster 13: peps, peps col, col, twist, peps twist, zer, peps zer, peps col twist, col twist, promoca
# Cluster 14: antarc, guar, guar antarc, antarc guar, antarc zer, zer, guar antarc zer, diet, promoca, chp antarc

# %% [markdown]
# #### Matriz de Confusão

# %%
plot_confusion_matrix(
    conf_mat=confusion_matrix(y_test, Y_Pred),
    figsize=(20, 20),
    show_absolute=False,
    show_normed=True,
    colorbar=True,
    class_names=np.unique(le.inverse_transform(y_test))
)
# Out:
# (<Figure size 1440x1440 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1227ea2d0>)
