# %% [markdown]
# # Naive Bayes
# ### Modelo 10
# - CountVectorizer
# - Base B
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_b.csv')

df.head()
# Out:
#                       nome categoria
# 0                   BRAHMA    BRAHMA
# 1             BRAHMA 550ML    BRAHMA
# 2     BRAHMA CERV 350ML LT    BRAHMA
# 3     BRAHMA CERVEJA 350ML    BRAHMA
# 4  BRAHMA CERVEJA 350ML LT    BRAHMA

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                       nome  categoria
# 0                   BRAHMA          0
# 1             BRAHMA 550ML          0
# 2     BRAHMA CERV 350ML LT          0
# 3     BRAHMA CERVEJA 350ML          0
# 4  BRAHMA CERVEJA 350ML LT          0

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Lista de Stop Words

# %%
stopwords_arquivo = pd.read_csv('../../stopwords.csv')

lista_stop_words = [ token(word)[0] for word in stopwords_arquivo.stopwords.values ]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome,
    df.categoria,
    test_size = 0.3,
    random_state = 42
)

# %% [markdown]
# #### Define CountVectorizer

# %%
count_vectorizer = CountVectorizer(
    tokenizer=token,
    ngram_range=(1,3),
    stop_words=lista_stop_words
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = count_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Cria um classificador Naive Bayes

# %%
model = GaussianNB()

# %% [markdown]
# #### Treina o classificador

# %%
model.fit(X_train.toarray(), y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = model.predict(count_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 92.7
# precisao: 93.6

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = count_vectorizer.transform([X_test.values[i]])
    pred = model.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                  Nome Categoria Original  \
# 0               SUCO DE UVA SPRES 2LT           SUCO UVA
# 1           SUCO PRAT S LARANJA 900ML       SUCO LARANJA
# 2              SUCO DAFRUTA LARANJA P       SUCO LARANJA
# 3      SUCO DE UVA INTEGRAL VIVAFELIZ  SUCO UVA INTEGRAL
# 4     SUCO D VALLE FRESH 1 5L UVA PET           SUCO UVA
# ..                                ...                ...
# 61              SUCO APTI LARANJA 30G       SUCO LARANJA
# 62                SUCO LARANJA 300 ML       SUCO LARANJA
# 63               REFRIG COCA COLA ZER          COCA-COLA
# 64  SUCO DEL VALLE FRESH LARANJA 1 5L       SUCO LARANJA
# 65               SUCO LARANJA M PR CP       SUCO LARANJA
#
#                      Pred
# 0            SUCO LARANJA
# 1   SUCO LARANJA INTEGRAL
# 2   SUCO LARANJA INTEGRAL
# 3   SUCO LARANJA INTEGRAL
# 4       SUCO UVA INTEGRAL
# ..                    ...
# 61  SUCO LARANJA INTEGRAL
# 62  SUCO LARANJA INTEGRAL
# 63         COCA-COLA ZERO
# 64  SUCO LARANJA INTEGRAL
# 65  SUCO LARANJA INTEGRAL
#
# [66 rows x 3 columns]

# %% [markdown]
# #### Gráfico

# %%
modelTSNE = TSNE(n_components=2, init='pca', random_state=0)
transformed = modelTSNE.fit_transform(X_train.todense())

fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], c=[plt.cm.tab20b(float(g)/15)], s=20, label = le.inverse_transform([g])[0])

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Matriz de Confusão

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_confusion_matrix(
    model,
    count_vectorizer.transform(X_test).toarray(),
    y_test,
    display_labels=np.unique(le.inverse_transform(y_test)),
    cmap=plt.cm.Blues,
    normalize='true',
    ax=ax,
    xticks_rotation='vertical'
)
