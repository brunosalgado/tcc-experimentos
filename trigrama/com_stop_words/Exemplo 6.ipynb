# %% [markdown]
# # K-Nearest Neighbors
# ### Modelo 06
# - CountVectorizer
# - Base B
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, mean_squared_error, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_b.csv')

df.head()
# Out:
#                       nome categoria
# 0                   BRAHMA    BRAHMA
# 1             BRAHMA 550ML    BRAHMA
# 2     BRAHMA CERV 350ML LT    BRAHMA
# 3     BRAHMA CERVEJA 350ML    BRAHMA
# 4  BRAHMA CERVEJA 350ML LT    BRAHMA

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                       nome  categoria
# 0                   BRAHMA          0
# 1             BRAHMA 550ML          0
# 2     BRAHMA CERV 350ML LT          0
# 3     BRAHMA CERVEJA 350ML          0
# 4  BRAHMA CERVEJA 350ML LT          0

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Lista de Stop Words

# %%
stopwords_arquivo = pd.read_csv('../../stopwords.csv')

lista_stop_words = [ token(word)[0] for word in stopwords_arquivo.stopwords.values ]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome, 
    df.categoria,
    test_size = 0.3, 
    random_state = 42
)

# %% [markdown]
# #### Define CountVectorizer

# %%
count_vectorizer = CountVectorizer(
    tokenizer=token,
    ngram_range=(1,3),
    stop_words=lista_stop_words
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = count_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Busca melhor valor para k

# %%
best_rmse = 1
k_neighbors = 0

k_range = range(1, 31)
k_scores = []
for k in k_range:
    model = KNeighborsClassifier(n_neighbors=k)
    loss = abs(cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error'))
    k_scores.append(loss.mean())
    if loss.mean() < best_rmse:
        best_rmse = loss.mean()
        k_neighbors = k
plt.plot(k_range, k_scores)
plt.xlabel('Valor de K')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# #### Cria um classificador kNN

# %%
knn = KNeighborsClassifier(n_neighbors = k_neighbors)

# %% [markdown]
# #### Treina o classificador

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = knn.predict(count_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 96.6
# precisao: 96.8

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = count_vectorizer.transform([X_test.values[i]])
    pred = knn.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                                  Nome     Categoria Original  \
# 0                                SUCO INT LARANJA 1LT  SUCO LARANJA INTEGRAL
# 1                              SUCO DAFRUTA LARANJA P           SUCO LARANJA
# 2                  SUCO DEL VALLE FRESH LARANJA 400ML           SUCO LARANJA
# 3               SUCO ALIANCA UVA BRANCO INTEG GFA 1.5      SUCO UVA INTEGRAL
# 4                SUCO ALIANCA UVA BCO INTEGRAL GFA 1L      SUCO UVA INTEGRAL
# 5                  SUCO DE MAMAO COM LARANJA INTEGRAL  SUCO LARANJA INTEGRAL
# 6            SUCO DE UVA TINTO INT HUGO PIETRO 1500ML      SUCO UVA INTEGRAL
# 7   SUCO MAGUARY VITAKIDS DISNEY CARROS LARANJA CX...           SUCO LARANJA
# 8                  SUCO DEL VALLE 100 UVA INTEGRAL 1L      SUCO UVA INTEGRAL
# 9                                SUCO SOJA LARANJA 1L           SUCO LARANJA
# 10        SUCO CAMPO LARGO GOL LARANJA INTEGRAL 250ML  SUCO LARANJA INTEGRAL
# 11            SUCO CAMPO LARGO GOL UVA INTEGRAL 250ML      SUCO UVA INTEGRAL
# 12                               SUCO UVA TINTO INT P      SUCO UVA INTEGRAL
# 13                        SUCO UVA PRIMA DUO INTEGRAL      SUCO UVA INTEGRAL
# 14              SUCO NATURAL ONE LARANJA INT GFA 900M  SUCO LARANJA INTEGRAL
# 15  SUCO DE MACA LARANJA INTEGRAL E MANGA SUVALAN ...  SUCO LARANJA INTEGRAL
# 16              SUCO FRUT LARANJA DEL VALLE PET 450ML           SUCO LARANJA
# 17                   SUCO ALIANCA UVA INTEGRAL GFA 1L      SUCO UVA INTEGRAL
# 18                              SUCO CAMP LAR LARANJA           SUCO LARANJA
# 19                             SUCO MAG LARANJA 500ML           SUCO LARANJA
# 20              BEBIDAS DIVERSAS SUCO CAMPO LARGO UVA               SUCO UVA
# 21                      SUCO NECTA MAGUARY 1L LARANJA           SUCO LARANJA
# 22               SUCO DA FRUTA LARANJA INTEGRAL 200ML  SUCO LARANJA INTEGRAL
# 23                          SUCO TANG UVA INTENSA 25G      SUCO UVA INTEGRAL
# 24              SUCO PANIZZON UVA BRANCO INTEG GFA 1.      SUCO UVA INTEGRAL
# 25                     REFRIG FANTA SPRITE KUAT 600ML                   KUAT
# 26                      SUCO ADES LARANJA INTEGRAL 1L  SUCO LARANJA INTEGRAL
# 27             SUCO DEL VALLE FRESH LARANJA PET 400ML           SUCO LARANJA
# 28                 SUCO ALIANCA UVA TINTO INTEG 450ML      SUCO UVA INTEGRAL
# 29                               REFRIG COCA COLA ZER              COCA-COLA
# 30                  SUCO DEL VALLE FRESH LARANJA 1 5L           SUCO LARANJA
#
#                      Pred
# 0       SUCO UVA INTEGRAL
# 1                SUCO UVA
# 2   SUCO LARANJA INTEGRAL
# 3                SUCO UVA
# 4                SUCO UVA
# 5            SUCO LARANJA
# 6                SUCO UVA
# 7                SUCO UVA
# 8                SUCO UVA
# 9   SUCO LARANJA INTEGRAL
# 10           SUCO LARANJA
# 11               SUCO UVA
# 12               SUCO UVA
# 13               SUCO UVA
# 14           SUCO LARANJA
# 15      SUCO UVA INTEGRAL
# 16               SUCO UVA
# 17               SUCO UVA
# 18  SUCO LARANJA INTEGRAL
# 19               SUCO UVA
# 20      SUCO UVA INTEGRAL
# 21               SUCO UVA
# 22      SUCO UVA INTEGRAL
# 23               SUCO UVA
# 24               SUCO UVA
# 25                  FANTA
# 26           SUCO LARANJA
# 27  SUCO LARANJA INTEGRAL
# 28               SUCO UVA
# 29         COCA-COLA ZERO
# 30  SUCO LARANJA INTEGRAL

# %%
model = TSNE(n_components=2, init='pca', random_state=0)
transformed = model.fit_transform(X_train.todense())

fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], c=[plt.cm.tab20b(float(g)/15)], s=20, label = le.inverse_transform([g])[0])

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Matriz de Confusão

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_confusion_matrix(
    knn,
    count_vectorizer.transform(X_test).toarray(),
    y_test,
    display_labels=np.unique(le.inverse_transform(y_test)),
    cmap=plt.cm.Blues,
    normalize='true',
    ax=ax,
    xticks_rotation='vertical'
)
