# %% [markdown]
# # K-Nearest Neighbors
# ### Modelo 07
# - TfidfVectorizer
# - Base A
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, mean_squared_error, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_a.csv')

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA   SUCO UVA
# 1                           110 PEPSI LIGHT      PEPSI
# 2                              2L COCA COLA  COCA-COLA
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML     SPRITE
# 4                               AGUA SPRITE     SPRITE

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA         13
# 1                           110 PEPSI LIGHT          8
# 2                              2L COCA COLA          2
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML         10
# 4                               AGUA SPRITE         10

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome, 
    df.categoria,
    test_size = 0.3, 
    random_state = 42
)

# %% [markdown]
# #### Define TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(
    tokenizer=token,
    ngram_range=(1,3)
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = tfidf_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Busca melhor valor para k

# %%
best_rmse = 1
k_neighbors = 0

k_range = range(1, 31)
k_scores = []
for k in k_range:
    model = KNeighborsClassifier(n_neighbors=k)
    loss = abs(cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error'))
    k_scores.append(loss.mean())
    if loss.mean() < best_rmse:
        best_rmse = loss.mean()
        k_neighbors = k
plt.plot(k_range, k_scores)
plt.xlabel('Valor de K')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# #### Cria um classificador kNN

# %%
knn = KNeighborsClassifier(n_neighbors = k_neighbors)

# %% [markdown]
# #### Treina o classificador

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=26)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = knn.predict(tfidf_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 94.5
# precisao: 94.9

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = tfidf_vectorizer.transform([X_test.values[i]])
    pred = knn.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                         Nome     Categoria Original  \
# 0       SUCO DE LARANJA INTEGRAL PRATS 900ML  SUCO LARANJA INTEGRAL
# 1               SUCO AURORA INT UVA BCO 1.5L      SUCO UVA INTEGRAL
# 2    SUCO SUVALAN MACA LARANJA BETERRABA 1LT           SUCO LARANJA
# 3                          SUCO TANG UVA 30G               SUCO UVA
# 4                            GUARANA ZR LATA      GUARANA ANTARTICA
# 5                       REFRI COCA COLA ZERO         COCA-COLA ZERO
# 6             SUCO INTEGRAL DE LARANJA 300ML  SUCO LARANJA INTEGRAL
# 7                      CINI MIX LARANJA 1 5L      CINI REFRIGERANTE
# 8             SUCO LARANJA CAMPO LARGO 900ML           SUCO LARANJA
# 9            SUCO CAMPO LARGO LARANJA 1.35 L           SUCO LARANJA
# 10              GUARANA ANTART ZERO LT 350ML      GUARANA ANTARTICA
# 11        SUCO CAMPO LARGO GOL LARANJA 250ML           SUCO LARANJA
# 12                      SUCO MAGUARY LARANJA           SUCO LARANJA
# 13              REF LATA FANTA GUARANA 220ML      GUARANA ANTARTICA
# 14                      GV SUCO DE UVA INTEG      SUCO UVA INTEGRAL
# 15               SUCO KAPO LARANJA INF 200ML  SUCO LARANJA INTEGRAL
# 16          REFRIG COCA COLA SPRITE 2L LV PG                 SPRITE
# 17            SUCO MAGUARY NECTAR LARANJA 1L           SUCO LARANJA
# 18            SUCO NATURAL ONE 900ML LARANJA           SUCO LARANJA
# 19          SUCO CAMPO LARGO UVA INTEGRAL 90      SUCO UVA INTEGRAL
# 20  SUCO DE LARANJA VIVA FELIZ 330ML INTEGRA  SUCO LARANJA INTEGRAL
# 21             SUCO PRATS LARANJA INTG 330ML  SUCO LARANJA INTEGRAL
# 22                      COCA COLA 200ML ZERO         COCA-COLA ZERO
# 23                   SUCO UVA SU FRESH 200ML               SUCO UVA
# 24                         SUCO TANG UVA 25G               SUCO UVA
# 25                         COCA COLA 1L ZERO         COCA-COLA ZERO
# 26                      SUCO INT LARANJA 1LT  SUCO LARANJA INTEGRAL
# 27                      REFRIG COCA COLA ZER              COCA-COLA
# 28         SUCO INTEG UVA 300 ML NOVO CITRUS      SUCO UVA INTEGRAL
# 29                            PEPSI ZERO 2LT                  PEPSI
# 30                   SUCO TANG UVA VERDE 25G               SUCO UVA
# 31               SUCO UVA PRIMA DUO INTEGRAL      SUCO UVA INTEGRAL
# 32                        GUARANA 2 LTS UN E      GUARANA ANTARTICA
# 33                        FANTA GUAR ZERO 2L                  FANTA
# 34                COCA COLA LATA ZERO 350 ML         COCA-COLA ZERO
# 35                 SUCO TANG UVA INTENSA 25G      SUCO UVA INTEGRAL
# 36                    SUCO PRATS UVA INT 900      SUCO UVA INTEGRAL
# 37                          GUARANA 2 LITROS      GUARANA ANTARTICA
# 38                         SUCO DE UVA INTEG      SUCO UVA INTEGRAL
# 39                    REF COCA COLA 1 L ZERO         COCA-COLA ZERO
# 40  BELLA VITTA SUCO UVA TINTO INTEGRAL 1 5L      SUCO UVA INTEGRAL
# 41   SUCO CAMPO LARGO INTEGRAL LARANJA 900ML  SUCO LARANJA INTEGRAL
# 42                         SUCO DE UVA INT E      SUCO UVA INTEGRAL
# 43         SUCO LIFE LARANJA INTEGRAL GFA 5L  SUCO LARANJA INTEGRAL
# 44                      SKOL SENSES LN 313ML                   SKOL
# 45      BEB SUCO UVA AURORA INTEG TINTO 1 5L      SUCO UVA INTEGRAL
# 46             SUCO PRATS LARANJA INTG 900ML  SUCO LARANJA INTEGRAL
# 47     SUCO DOM ELISEO INTEG UVA TINTO 1L GF      SUCO UVA INTEGRAL
# 48         SUCO MAGUARY NECTAR LARANJA TP 1L           SUCO LARANJA
# 49      SUCO DE LARANJA INTEGRAL PRATS 1 7 L  SUCO LARANJA INTEGRAL
# 50                SUCO MAGUARY 200ML LARANJA           SUCO LARANJA
# 51           SUCO BONBON UVA COM COCO HAITAI               SUCO UVA
# 52   SUCO NATURAL ONE INTEGRAL LARANJA 900ML  SUCO LARANJA INTEGRAL
# 53                     SUCO PRATS UVA 330 ML               SUCO UVA
# 54          SUCO CASA PERINI INTEG UVA 1L GF      SUCO UVA INTEGRAL
# 55          REF LATA FANTA GUARANA 200ML PET      GUARANA ANTARTICA
# 56  SUCO FRAMB E UVAS BRAN INTEG NOBRE COLHE      SUCO UVA INTEGRAL
# 57        SUCO ALIANCA UVA TINTO INTEG 450ML      SUCO UVA INTEGRAL
# 58      SUCO DE LARANJA INTEGRAL 1LT SUCOESO  SUCO LARANJA INTEGRAL
#
#                  Pred
# 0        SUCO LARANJA
# 1            SUCO UVA
# 2            SUCO UVA
# 3        SUCO LARANJA
# 4               FANTA
# 5           COCA-COLA
# 6        SUCO LARANJA
# 7        SUCO LARANJA
# 8            SUCO UVA
# 9            SUCO UVA
# 10     COCA-COLA ZERO
# 11           SUCO UVA
# 12           SUCO UVA
# 13              FANTA
# 14           SUCO UVA
# 15       SUCO LARANJA
# 16          COCA-COLA
# 17           SUCO UVA
# 18           SUCO UVA
# 19           SUCO UVA
# 20       SUCO LARANJA
# 21       SUCO LARANJA
# 22          COCA-COLA
# 23             SPRITE
# 24       SUCO LARANJA
# 25          COCA-COLA
# 26       SUCO LARANJA
# 27     COCA-COLA ZERO
# 28           SUCO UVA
# 29     COCA-COLA ZERO
# 30       SUCO LARANJA
# 31           SUCO UVA
# 32              FANTA
# 33     COCA-COLA ZERO
# 34          COCA-COLA
# 35       SUCO LARANJA
# 36       SUCO LARANJA
# 37          COCA-COLA
# 38           SUCO UVA
# 39          COCA-COLA
# 40           SUCO UVA
# 41           SUCO UVA
# 42           SUCO UVA
# 43       SUCO LARANJA
# 44             BRAHMA
# 45           SUCO UVA
# 46       SUCO LARANJA
# 47           SUCO UVA
# 48           SUCO UVA
# 49       SUCO LARANJA
# 50           SUCO UVA
# 51          COCA-COLA
# 52       SUCO LARANJA
# 53       SUCO LARANJA
# 54           SUCO UVA
# 55              FANTA
# 56  CINI REFRIGERANTE
# 57           SUCO UVA
# 58       SUCO LARANJA

# %%
model = TSNE(n_components=2, init='pca', random_state=0)
transformed = model.fit_transform(X_train.todense())

fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], c=[plt.cm.tab20b(float(g)/15)], s=20, label = le.inverse_transform([g])[0])

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Matriz de Confusão

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_confusion_matrix(
    knn,
    tfidf_vectorizer.transform(X_test).toarray(),
    y_test,
    display_labels=np.unique(le.inverse_transform(y_test)),
    cmap=plt.cm.Blues,
    normalize='true',
    ax=ax,
    xticks_rotation='vertical'
)
