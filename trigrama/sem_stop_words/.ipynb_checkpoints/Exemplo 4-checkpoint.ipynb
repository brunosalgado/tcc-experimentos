# %% [markdown]
# # k-means
# ### Modelo 04
# - TfidfVectorizer
# - Base B
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_b.csv')

df.head()
# Out:
#                       nome categoria
# 0                   BRAHMA    BRAHMA
# 1             BRAHMA 550ML    BRAHMA
# 2     BRAHMA CERV 350ML LT    BRAHMA
# 3     BRAHMA CERVEJA 350ML    BRAHMA
# 4  BRAHMA CERVEJA 350ML LT    BRAHMA

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                       nome  categoria
# 0                   BRAHMA          0
# 1             BRAHMA 550ML          0
# 2     BRAHMA CERV 350ML LT          0
# 3     BRAHMA CERVEJA 350ML          0
# 4  BRAHMA CERVEJA 350ML LT          0

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome,
    df.categoria,
    test_size = 0.3,
    random_state = 42
)

# %% [markdown]
# #### Define TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(
    tokenizer=token,
    ngram_range=(1,3)
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = tfidf_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Cria um classificador k-means

# %%
kmeans = KMeans(
    n_clusters = 15,
    random_state=24
)

# %% [markdown]
# #### Treina o classificador

# %%
kmeans.fit(X_train.toarray(), y_train)
# Out:
# KMeans(n_clusters=15, random_state=24)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = kmeans.predict(tfidf_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 3.3
# precisao: 4.4

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = tfidf_vectorizer.transform([X_test.values[i]])
    pred = kmeans.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                    Nome     Categoria Original  \
# 0             CERV SKOL PURO MALTE 473M                   SKOL
# 1                     GUARANA PET 600ML      GUARANA ANTARTICA
# 2                    CERVEJA SKOL 550ML                   SKOL
# 3                  SUCO INT LARANJA 1LT  SUCO LARANJA INTEGRAL
# 4                           GUARANA ANT      GUARANA ANTARTICA
# ..                                  ...                    ...
# 865  SUCO DE LARANJA CAMPO LARGO 900 ML           SUCO LARANJA
# 866                  FANTA LATA LARANJA                  FANTA
# 867                 REFRIG SPRITE 350ML                 SPRITE
# 868                  CERVEJA BRAHMA LAT                 BRAHMA
# 869              CERV BRAHMA CHOPP LATA                 BRAHMA
#
#                       Pred
# 0    SUCO LARANJA INTEGRAL
# 1                    FANTA
# 2             SUCO LARANJA
# 3        GUARANA ANTARTICA
# 4                    FANTA
# ..                     ...
# 865         COCA-COLA ZERO
# 866      GUARANA ANTARTICA
# 867               GATORADE
# 868                  PEPSI
# 869                  PEPSI
#
# [870 rows x 3 columns]

# %% [markdown]
# #### Gráfico

# %%
model = PCA(n_components=2)
transformed = model.fit_transform(X_train.todense(), y_train)
fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], cmap='tab20b', s=20, label = le.inverse_transform([g])[0])

centers = model.transform(kmeans.cluster_centers_)
plt.scatter(centers[:, 0], centers[:, 1], s=300, c='black', alpha=0.5)

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Termos por cluster

# %%
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = tfidf_vectorizer.get_feature_names()
for i in range(15):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :10]]
    print("Cluster {}: {}".format(i, ', '.join(top_ten_words)))
# Out:
# Cluster 0: de uva, suc de uva, de, suc de, uva, de uva integr, suc, uva integr, integr, uva integr ml
# Cluster 1: coc, coc col, col, coc col ml, col ml, refr coc, ml, refr coc col, refr, refrig coc
# Cluster 2: kuat, guar, guar kuat, kuat ml, kuat guar, kuat zer, refrig kuat, refr kuat, ml, zer
# Cluster 3: de laranj, suc de laranj, de, suc de, laranj, de laranj integr, suc, laranj integr, integr, ml
# Cluster 4: guar, antarc, fant guar, guar antarc, antar, guar antar, guar ml, ml, fant, refr guar
# Cluster 5: sprit, refr sprit, sprit ml, refrig sprit, ml, refr, sprit lt, refrig, lt, fresh
# Cluster 6: suc, laranj, cin, fant, uva, ml, l, refrig, suc laranj, suc uva
# Cluster 7: del, del vall, vall, suc del, suc del vall, suc, laranj, del vall laranj, vall laranj, uva
# Cluster 8: brahm, cerv, cerv brahm, cervej brahm, cervej, chopp, ml, brahm chopp, brahm ml, brahm extr
# Cluster 9: peps, peps col, refrig peps, col, refr peps, refrig peps col, refrig, l, twist, peps ml
# Cluster 10: coc col zer, col zer, coc col, zer, coc, col, col zer ml, zer ml, refr coc col, refr coc
# Cluster 11: skol, beat, skol beat, cerv skol, cervej skol, cerv, ml, cervej, skol ml, skol lat
# Cluster 12: pur, skol pur, pur malt, malt, skol pur malt, skol, cerv skol pur, cerv skol, cervej skol pur, cerv
# Cluster 13: camp larg, larg, camp, suc camp larg, suc camp, suc, larg uva, camp larg uva, uva, integr
# Cluster 14: gatorad, ml, gatorad ml, maracuj, isoton, beb, gatorad uva, isot, isot gatorad, beb gatorad

# %% [markdown]
# #### Matriz de Confusão

# %%
plot_confusion_matrix(
    conf_mat=confusion_matrix(y_test, Y_Pred),
    figsize=(20, 20),
    show_absolute=False,
    show_normed=True,
    colorbar=True,
    class_names=np.unique(le.inverse_transform(y_test))
)
# Out:
# (<Figure size 1440x1440 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1248cafd0>)
