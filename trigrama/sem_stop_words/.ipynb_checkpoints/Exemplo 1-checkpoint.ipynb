# %% [markdown]
# # k-means
# ### Modelo 01
# - CountVectorizer
# - Base A
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_a.csv')

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA   SUCO UVA
# 1                           110 PEPSI LIGHT      PEPSI
# 2                              2L COCA COLA  COCA-COLA
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML     SPRITE
# 4                               AGUA SPRITE     SPRITE

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA         13
# 1                           110 PEPSI LIGHT          8
# 2                              2L COCA COLA          2
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML         10
# 4                               AGUA SPRITE         10

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome,
    df.categoria,
    test_size = 0.3,
    random_state = 42
)

# %% [markdown]
# #### Define CountVectorizer

# %%
count_vectorizer = CountVectorizer(
    tokenizer=token,
    ngram_range=(1,3)
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = count_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Cria um classificador k-means

# %%
kmeans = KMeans(
    n_clusters = 15,
    random_state=24
)

# %% [markdown]
# #### Treina o classificador

# %%
kmeans.fit(X_train.toarray(), y_train)
# Out:
# KMeans(n_clusters=15, random_state=24)

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = kmeans.predict(count_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 1.2
# precisao: 1.0

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = count_vectorizer.transform([X_test.values[i]])
    pred = kmeans.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                       Nome     Categoria Original  \
# 0          CERV SKOL BEATS SENSES LN 313ML                   SKOL
# 1                     REF PET SPRITE 1 5LT                 SPRITE
# 2                     GATORADE MORAN MARAC               GATORADE
# 3            REFRIGERANTE SPRITE LIMA O 2L                 SPRITE
# 4             SUCO DEL VALLE UVA SAC 200ML               SUCO UVA
# ...                                    ...                    ...
# 1047           REFR FANTA GUARANA LT 350ML                  FANTA
# 1048                  REFRI ZERO FANTA LAR                  FANTA
# 1049                     GUARANA KUAT LATA                   KUAT
# 1050  SUCO DE LARANJA INTEGRAL 1LT SUCOESO  SUCO LARANJA INTEGRAL
# 1051                  REFRIG CINI 2L LIMAO      CINI REFRIGERANTE
#
#                        Pred
# 0                  GATORADE
# 1                     FANTA
# 2                      SKOL
# 3                     FANTA
# 4                    SPRITE
# ...                     ...
# 1047      CINI REFRIGERANTE
# 1048              COCA-COLA
# 1049           SUCO LARANJA
# 1050                   KUAT
# 1051  SUCO LARANJA INTEGRAL
#
# [1052 rows x 3 columns]

# %% [markdown]
# #### Gráfico

# %%
model = PCA(n_components=2)
transformed = model.fit_transform(X_train.todense(), y_train)
fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], cmap='tab20b', s=20, label = le.inverse_transform([g])[0])

centers = model.transform(kmeans.cluster_centers_)
plt.scatter(centers[:, 0], centers[:, 1], s=300, c='black', alpha=0.5)

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Termos por cluster

# %%
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = count_vectorizer.get_feature_names()
for i in range(15):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :10]]
    print("Cluster {}: {}".format(i, ', '.join(top_ten_words)))
# Out:
# Cluster 0: peps, col, peps col, refrig, refrig peps, l, pet, refrig peps col, ml, pet l
# Cluster 1: guar, ml, antarc, l, fant, refr, fant guar, guar antarc, zer, refrig
# Cluster 2: fant, laranj, ml, fant laranj, lat, refrig, refrig fant, refr fant, refr, l
# Cluster 3: coc, coc col, col, ml, col ml, coc col ml, l, refr coc, refr, refr coc col
# Cluster 4: sprit, ml, refrig sprit, refrig, pet, refr sprit, refr, l, fresh, sprit ml
# Cluster 5: skol, ml, cerv, cerv skol, beat, skol beat, lt, cervej, cervej skol, skol ml
# Cluster 6: uva, fant, fant uva, ml, uva ml, refrig, refrig fant uva, refrig fant, refr, fant uva ml
# Cluster 7: suc, laranj, ml, de, de laranj, suc de, l, suc laranj, suc de laranj, laranj ml
# Cluster 8: skol, malt, pur malt, pur, skol pur, skol pur malt, ml, cerv, cerv skol, cerv skol pur
# Cluster 9: ml, cin, gatorad, refr, l, peps, coc, refr cin, ref, zer
# Cluster 10: suc, uva, ml, suc uva, l, de, de uva, suc de uva, suc de, uva ml
# Cluster 11: kuat, ml, guar, l, refr, kuat ml, pet, guar kuat, refr kuat, refrig
# Cluster 12: refrig, cin, refrig cin, l, pet, ml, pet l, cin gengibirr, frambo, refrig cin gengibirr
# Cluster 13: brahm, ml, cerv, cerv brahm, cervej, cervej brahm, chopp, brahm chopp, lt, ln
# Cluster 14: zer, coc, coc col, col zer, col, coc col zer, ml, col zer ml, zer ml, l

# %% [markdown]
# #### Matriz de Confusão

# %%
plot_confusion_matrix(
    conf_mat=confusion_matrix(y_test, Y_Pred),
    figsize=(20, 20),
    show_absolute=False,
    show_normed=True,
    colorbar=True,
    class_names=np.unique(le.inverse_transform(y_test))
)
# Out:
# (<Figure size 1440x1440 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11c9f3f10>)
