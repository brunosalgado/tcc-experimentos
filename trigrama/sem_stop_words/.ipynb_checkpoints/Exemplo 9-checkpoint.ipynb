# %% [markdown]
# # Naive Bayes
# ### Modelo 09
# - CountVectorizer
# - Base A
#
#
# #### Imports necessarios para funcionamento da aplicacao

# %%
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score
from nltk import word_tokenize
from nltk.stem import RSLPStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #### Leitura do arquivo de dados

# %%
df = pd.read_csv('../../base_a.csv')

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA   SUCO UVA
# 1                           110 PEPSI LIGHT      PEPSI
# 2                              2L COCA COLA  COCA-COLA
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML     SPRITE
# 4                               AGUA SPRITE     SPRITE

# %% [markdown]
# #### Efetua o tratamento dos dados

# %%
le = LabelEncoder()

df.categoria = le.fit_transform(df.categoria)

df.head()
# Out:
#                                        nome  categoria
# 0                          1051 SUCO DE UVA         13
# 1                           110 PEPSI LIGHT          8
# 2                              2L COCA COLA          2
# 3  AGUA SABORIZADA SPRITE LEMON FRESH 510ML         10
# 4                               AGUA SPRITE         10

# %% [markdown]
# #### Função de tokenização

# %%
stemmer = RSLPStemmer()

def token(text):
    text = re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', ' ', text)
    txt = word_tokenize(text.lower())
    return [stemmer.stem(word) for word in txt]

# %% [markdown]
# #### Separa base de treino e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df.nome,
    df.categoria,
    test_size = 0.3,
    random_state = 42
)

# %% [markdown]
# #### Define CountVectorizer

# %%
count_vectorizer = CountVectorizer(
    tokenizer=token,
    ngram_range=(1,3)
)

# %% [markdown]
# #### Cria vocabulário

# %%
X_train = count_vectorizer.fit_transform(X_train.values)

# %% [markdown]
# ## Etapa de treinamento
# #### Cria um classificador Naive Bayes

# %%
model = GaussianNB()

# %% [markdown]
# #### Treina o classificador

# %%
model.fit(X_train.toarray(), y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ## Etapa de Teste
#
# #### Efetua a predição

# %%
Y_Pred = model.predict(count_vectorizer.transform(X_test).toarray())

# %% [markdown]
# #### Calcula a acurácia do classificador

# %%
print('acuracia: {:.1f}'.format(accuracy_score(y_test, Y_Pred) * 100))
print('precisao: {:.1f}'.format(precision_score(y_test, Y_Pred, average="weighted") * 100))
# Out:
# acuracia: 93.5
# precisao: 95.2

# %% [markdown]
# #### Tabela com os itens classificados errados na base de teste

# %%
d = []

for i in range(len(X_test)):
    au = count_vectorizer.transform([X_test.values[i]])
    pred = model.predict(au.toarray())
    if (y_test.values[i] != pred[0]):
        d.append(
            [
                X_test.values[i],
                le.inverse_transform([y_test.values[i]])[0],
                le.inverse_transform(pred)[0]
            ]
        )

df_error = pd.DataFrame(data=d,columns=['Nome','Categoria Original','Pred'])
df_error
# Out:
#                                                 Nome Categoria Original  \
# 0                                SUCO DE UVA PORCINI           SUCO UVA
# 1                              SUCO DE LARANJA 900ML       SUCO LARANJA
# 2   GUARANA CHP ANTARCTICA LATA 350ML SH C 12 NPAL L  GUARANA ANTARTICA
# 3                             SUCO ACEROLA E LARANJA       SUCO LARANJA
# 4                                 REFRI FANTA GUA 3L              FANTA
# ..                                               ...                ...
# 64                                 SUCO E SO LARANJA       SUCO LARANJA
# 65                   SUCO NECTAR DA FRUTA 1L LARANJA       SUCO LARANJA
# 66                    SUCO ALIANCA UVA TINTO 1 5L GF           SUCO UVA
# 67                  REF LATA FANTA GUARANA 200ML PET  GUARANA ANTARTICA
# 68                                     SUCO UVA AGUA           SUCO UVA
#
#                      Pred
# 0       SUCO UVA INTEGRAL
# 1   SUCO LARANJA INTEGRAL
# 2                   PEPSI
# 3   SUCO LARANJA INTEGRAL
# 4                    KUAT
# ..                    ...
# 64  SUCO LARANJA INTEGRAL
# 65               SUCO UVA
# 66      SUCO UVA INTEGRAL
# 67                  FANTA
# 68      SUCO UVA INTEGRAL
#
# [69 rows x 3 columns]

# %% [markdown]
# #### Gráfico

# %%
modelTSNE = TSNE(n_components=2, init='pca', random_state=0)
transformed = modelTSNE.fit_transform(X_train.todense())

fig, ax = plt.subplots(figsize=(8,8))

for g in np.unique(y_train):
    ix = np.where(y_train == g)
    ax.scatter(transformed[:,0][ix], transformed[:,1][ix], c=[plt.cm.tab20b(float(g)/15)], s=20, label = le.inverse_transform([g])[0])

plt.legend(loc='lower left',fontsize=7)
plt.axhline(color='b')
plt.axvline(color='b')
plt.show()

# %% [markdown]
# #### Matriz de Confusão

# %%
fig, ax = plot_confusion_matrix(
    conf_mat=confusion_matrix(y_test, Y_Pred),
    figsize=(11, 11),
    show_absolute=False,
    show_normed=True,
    class_names=np.unique(le.inverse_transform(y_test))
)

fig.subplots_adjust(bottom=0.2)

plt.xticks(rotation=90)
plt.xlabel('')
plt.ylabel('')
# plt.savefig('matriz-confusao-nb.png', dpi=fig.dpi)
plt.show()
